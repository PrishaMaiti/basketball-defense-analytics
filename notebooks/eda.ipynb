# %% [markdown]
# # Exploratory Data Analysis of Each Dataset (in Pairs of 2023 and 2024 Versions)

# %% [markdown]
# ## EDA #1: matchups

# %% [markdown]
# ## EDA #2: shotdetail

# %% [markdown]
# ## EDA #3: nbastatsv3

# %% [markdown]
# ## EDA #4: pbpstats
